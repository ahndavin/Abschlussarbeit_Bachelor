# %%
import os
#from scipy.io import loadmat
#import time

import pandas as pd
import numpy as np

#from tensorflow.keras.models import Model
#from tensorflow.keras.layers import Dense, Input, Dropout
#from tensorflow.keras.optimizers import Adam
#from tensorflow.keras import backend as K
#from tensorflow.random import set_seed

#from sklearn.ensemble import GradientBoostingRegressor
#from sklearn.metrics import mean_squared_error as mse, mean_absolute_error as mae, r2_score as r2
#from sklearn.inspection import permutation_importance

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import IsolationForest

# %%
df = pd.read_csv('data/teltow-full_train.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8517 entries, 0 to 8516
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  8517 non-null   object
#  1   sensor     8517 non-null   object
#  2   temp       8517 non-null   float64
#  3   regen      8517 non-null   float64
#  4   windGe     8517 non-null   float64
#  5   pm25       8517 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 399.4+ KB
# None

# %%
print(df.head())
# Out:
#              timestamp sensor       temp  regen    windGe       pm25
# 0  2022-03-16 13:00:00    218  22.786389    0.0  2.098333  20.145444
# 1  2022-03-16 13:00:00    215  22.786389    0.0  2.098333  17.499891
# 2  2022-03-16 13:00:00    216  22.786389    0.0  2.098333  19.745978
# 3  2022-03-16 13:00:00   DEUS  22.786389    0.0  2.098333  19.133118
# 4  2022-03-16 14:00:00   DEUS  24.075167    0.0  2.358500  22.177363

# %%
df.plot(subplots=True)
plt.show()
